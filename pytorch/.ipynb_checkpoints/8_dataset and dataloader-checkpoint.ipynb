# %%
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math

# %%
# !ls
# Out:
# 1_Basic pytorch.ipynb                  6_LnR.ipynb
# 2_autograd.ipynb                       7_LReg.ipynb
# 3_backpropgation.ipynb                 Neural network.ipynb
# 4_gradient descent with autograd.ipynb dataset and dataloader.ipynb
# 5_training pipeline.ipynb              wine.csv

# %%
class WineDataset(Dataset):
    def __init__(self):
        xy = np.loadtxt('./wine.csv', delimiter=",",dtype=np.float32, skiprows=1)
        self.x = torch.from_numpy(xy[:,1:])
        self.y = torch.from_numpy(xy[:,[0]])
        self.n_samples = xy.shape[0]
    def __getitem__(self, index):
        return self.x[index], self.y[index]
    def __len__(self):
        return self.n_samples

# %%
dataset = WineDataset()
first_data = dataset[0]
features, labels = first_data
print(features,labels)
# Out:
# tensor([1.4230e+01, 1.7100e+00, 2.4300e+00, 1.5600e+01, 1.2700e+02, 2.8000e+00,
#         3.0600e+00, 2.8000e-01, 2.2900e+00, 5.6400e+00, 1.0400e+00, 3.9200e+00,
#         1.0650e+03]) tensor([1.])

# %%
dataset1 = WineDataset()
dataloader = DataLoader(dataset=dataset1, batch_size=3,shuffle=True)

# %%
num_epochs = 2
total_samples = len(dataset1)
n_itertions = math.ceil(total_samples/3)
print(total_samples,n_itertions)
# Out:
# 178 60

# %%
for epoch in range(num_epochs):
    for i, (inputs, labels) in enumerate(dataloader):
        if (i+1) % 5 ==0 :
            print(f'epoch: {epoch+1}/{num_epochs}, step : {i+1}/{n_itertions}, inputs : {inputs.shape}')
# Out:
# epoch: 1/2, step : 5/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 10/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 15/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 20/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 25/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 30/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 35/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 40/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 45/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 50/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 55/60, inputs : torch.Size([3, 13])
# epoch: 1/2, step : 60/60, inputs : torch.Size([1, 13])
# epoch: 2/2, step : 5/60, inputs : torch.Size([3, 13])
# epoch: 2/2, step : 10/60, inputs : torch.Size([3, 13])
# epoch: 2/2, step : 15/60, inputs : torch.Size([3, 13])
# epoch: 2/2, step : 20/60, inputs : torch.Size([3, 13])
# epoch: 2/2, step : 25/60, inputs : torch.Size([3, 13])
# ...
